# %%
import pandas as pd

df = pd.read_csv('results.csv')
df
# Out:
#                        Method  Dataset  F1-score  Precision    Recall  \
# 0                 k-neighbors       og  0.838864   0.878568  0.842744
# 1                 k-neighbors      pca  0.991382   0.991383  0.991382
# 2                 k-neighbors  pearson  0.985381   0.985703  0.985384
# 3                 k-neighbors      lda  0.991175   0.991280  0.991175
# 4   supervised_neural_network       og  0.993312   0.993397  0.993313
# 5   supervised_neural_network      pca  0.991933   0.992001  0.991934
# 6   supervised_neural_network  pearson  0.991037   0.991127  0.991038
# 7   supervised_neural_network      lda  0.988141   0.988214  0.988142
# 8                 naive_bayes       og  0.941328   0.941436  0.941331
# 9                 naive_bayes      pca  0.874647   0.877387  0.874871
# 10                naive_bayes  pearson  0.869209   0.869351  0.869218
# 11                naive_bayes      lda  0.988348   0.988416  0.988349
# ...
